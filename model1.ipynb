# %% [markdown]
# # import libs we will use

# %%
import os 
import librosa as lr
import numpy as np
import pandas as pd

# %% [markdown]
# read files from folder

# %%
path = "./Wav/Train"
files = os.listdir(path)
df = pd.DataFrame(columns = ['max_pitch','avg_pitch','var_pitch','harmonic','harmonic_var','percussive','percussive_var','Chroma_cens','Chroma_cens_var','chroma_stft_mean','chroma_stft_var','chroma_cqt_mean','chroma_cqt_var','Mfccs','Mfccs_var','mfcc_delta_mean','mfcc_delta_var','Contrast','Contrast_var','Rolloff','Rolloff_var','Zrate','Zrate_var','Cent','Cent_var','tonnetz_mean','tonnetz_var','poly_features_mean','poly_features_var','spec_bw_mean','spec_bw_var','rmse_mean','rmse_var','melspec_mean','melspec_var','label'])
l=0
for f in files:
    if f[0] == 'c':
        label = 0
    elif f[0] == 'o':
        label = 1
    else:
        label = 2
    file_name = path+'/'+f
    audio,sfreq = lr.load(file_name)
    S = np.abs(lr.stft(audio))
    pitches,magnitudes = lr.core.piptrack(y = audio ,sr = sfreq)
    #min_pitch = np.min(pitches)
    max_pitch = np.max(pitches)
    avg_pitch = np.mean(pitches)
    var_pitch = np.var(pitches)
    y_harmonic, y_percussive = lr.effects.hpss(audio)
    #print(np.mean(y_harmonic),np.mean(y_percussive))
    harmonic = np.mean(y_harmonic)
    harmonic_var = np.var(y_harmonic)
    percussive = np.mean(y_percussive)
    percussive_var = np.var(y_percussive)
    chroma=lr.feature.chroma_cens(y=y_harmonic, sr=sfreq)
    #print(np.mean(chroma))
    Chroma_cens = np.mean(chroma)
    Chroma_cens_var = np.var(chroma)
    
    chroma_stft =lr.feature.chroma_stft(y=y_harmonic, sr=sfreq)
    chroma_stft_mean = np.mean(chroma_stft)
    chroma_stft_var = np.var(chroma_stft)
    
    chroma_cqt =lr.feature.chroma_cqt(y=y_harmonic, sr=sfreq)
    chroma_cqt_mean = np.mean(chroma_cqt)
    chroma_cqt_var = np.var(chroma_cqt)
    
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sfreq)
    #print(np.mean(mfccs))
    Mfccs = np.mean(mfccs)
    Mfccs_var = np.var(mfccs)
    delta = lr.feature.delta(mfccs)
    mfcc_delta_mean = np.mean(delta)
    mfcc_delta_var = np.var(delta)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sfreq)
    #print(np.mean(contrast))
    Contrast = np.mean(contrast)
    Contrast_var = np.var(contrast)
    
    rolloff = lr.feature.spectral_rolloff(y=audio, sr=sfreq)
    #print(np.mean(rolloff))
    Rolloff = np.mean(rolloff)
    Rolloff_var = np.var(rolloff)
    
    zrate=lr.feature.zero_crossing_rate(y_harmonic)
    #print(np.mean(zrate) )
    Zrate = np.mean(zrate)
    Zrate_var = np.var(zrate)
    
    cent = lr.feature.spectral_centroid(y=audio, sr=sfreq)
    Cent = np.mean(cent)
    Cent_var = np.var(cent)
    
    tonnetz = lr.feature.tonnetz(y=audio, sr=sfreq)
    tonnetz_mean = np.mean(tonnetz)
    tonnetz_var = np.var(tonnetz)
    
    poly_features = lr.feature.poly_features(S=S, sr=sfreq)
    poly_features_mean = np.mean(poly_features)
    poly_features_var = np.var(poly_features)
    
    spec_bw = lr.feature.spectral_bandwidth(y=audio, sr=sfreq)
    spec_bw_mean = np.mean(spec_bw)
    spec_bw_var = np.var(spec_bw)
    
    rmse = lr.feature.rms(y=audio)
    rmse_mean = np.mean(rmse)
    rmse_var = np.var(rmse)
    
    melspectrogram = lr.feature.melspectrogram(y=audio, sr=sfreq)
    melspec_mean = np.mean(melspectrogram)
    melspec_var = np.var(melspectrogram)
    
    data = list([max_pitch,avg_pitch,var_pitch,harmonic,harmonic_var,percussive,percussive_var,Chroma_cens,Chroma_cens_var,chroma_stft_mean,chroma_stft_var,chroma_cqt_mean,chroma_cqt_var,Mfccs,Mfccs_var,mfcc_delta_mean,mfcc_delta_var,Contrast,Contrast_var,Rolloff,Rolloff_var,Zrate,Zrate_var,Cent,Cent_var,tonnetz_mean,tonnetz_var,poly_features_mean,poly_features_var,spec_bw_mean,spec_bw_var,rmse_mean,rmse_var,melspec_mean,melspec_var,label])
    df.loc[l] = data
    l+=1
# Out:
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=794
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=993
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=993
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=912
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=963
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=1015
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=905
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=963
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=721
#   return f(*args, **kwargs)

# %%
df.head()
# Out:
#      max_pitch  avg_pitch     var_pitch      harmonic  harmonic_var  \
# 0  3422.763916   8.604278  10254.308594  7.945924e-07      0.001547
# 1  3613.870850   7.523058  11552.167969 -5.989882e-08      0.000769
# 2  3992.850342  10.505054  14567.119141  6.744334e-07      0.000607
# 3  3989.072998  29.542696  74463.960938  1.135538e-08      0.000019
# 4  3994.850098   3.910675   5684.229980 -2.893094e-08      0.000001
#
#      percussive  percussive_var  Chroma_cens  Chroma_cens_var  \
# 0 -1.227648e-06        0.000233     0.227343         0.031648
# 1 -5.383673e-07        0.000145     0.223962         0.033174
# 2  8.096249e-07        0.000077     0.223486         0.033387
# 3 -2.912421e-07        0.000281     0.190124         0.047186
# 4  6.930518e-08        0.000624     0.179645         0.051061
#
#    chroma_stft_mean  ...  tonnetz_var  poly_features_mean  poly_features_var  \
# 0          0.340030  ...     0.009707            0.206809           0.229776
# 1          0.354331  ...     0.010545            0.120110           0.098493
# 2          0.382184  ...     0.014960            0.109452           0.067811
# 3          0.323848  ...     0.016131            0.070689           0.051435
# 4          0.223615  ...     0.020018            0.099285           0.141008
#
#    spec_bw_mean    spec_bw_var  rmse_mean  rmse_var  melspec_mean  \
# 0   1759.880102  179896.281634   0.025057  0.001347      0.455951
# 1   1911.819191  145753.474875   0.016154  0.000765      0.236250
# 2   1839.995402  109216.482804   0.014866  0.000550      0.179522
# 3   2282.245967  556910.078353   0.008684  0.000311      0.090904
# 4   2238.714948  321685.673006   0.012220  0.000486      0.126759
#
#    melspec_var  label
# 0    35.669964    0.0
# 1    15.527596    0.0
# 2     8.766246    0.0
# 3     2.283215    0.0
# 4     3.516226    0.0
#
# [5 rows x 36 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
X_train = df.drop(columns='label',axis=1)
Y_train = df['label']

# %%
classifier = RandomForestClassifier(n_estimators=50,max_features="auto",random_state=44)
classifier.fit(X_train,Y_train)
# Out:
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomForestClassifier(max_features='auto', n_estimators=50, random_state=44)

# %%
y_hat_train = classifier.predict(X_train)
training_data_accuracy = accuracy_score(y_hat_train, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  1.0

# %%
path = "./Wav/Test"
files = os.listdir(path)
df_t = pd.DataFrame(columns = ['max_pitch','avg_pitch','var_pitch','harmonic','harmonic_var','percussive','percussive_var','Chroma_cens','Chroma_cens_var','chroma_stft_mean','chroma_stft_var','chroma_cqt_mean','chroma_cqt_var','Mfccs','Mfccs_var','mfcc_delta_mean','mfcc_delta_var','Contrast','Contrast_var','Rolloff','Rolloff_var','Zrate','Zrate_var','Cent','Cent_var','tonnetz_mean','tonnetz_var','poly_features_mean','poly_features_var','spec_bw_mean','spec_bw_var','rmse_mean','rmse_var','melspec_mean','melspec_var','label'])
l=0
for f in files:
    if f[0] == 'c' or f[0]=='C':
        label = 0
    elif f[0] == 'o' or f[0] == 'O':
        label = 1
    else: 
        label = 2
    file_name = path+'/'+f
    audio,sfreq = lr.load(file_name)
    S = np.abs(lr.stft(audio))
    pitches,magnitudes = lr.core.piptrack(y = audio ,sr = sfreq)
    #min_pitch = np.min(pitches)
    max_pitch = np.max(pitches)
    avg_pitch = np.mean(pitches)
    var_pitch = np.var(pitches)
    y_harmonic, y_percussive = lr.effects.hpss(audio)
    #print(np.mean(y_harmonic),np.mean(y_percussive))
    harmonic = np.mean(y_harmonic)
    harmonic_var = np.var(y_harmonic)
    percussive = np.mean(y_percussive)
    percussive_var = np.var(y_percussive)
    chroma=lr.feature.chroma_cens(y=y_harmonic, sr=sfreq)
    #print(np.mean(chroma))
    Chroma_cens = np.mean(chroma)
    Chroma_cens_var = np.var(chroma)
    
    chroma_stft =lr.feature.chroma_stft(y=y_harmonic, sr=sfreq)
    chroma_stft_mean = np.mean(chroma_stft)
    chroma_stft_var = np.var(chroma_stft)
    
    chroma_cqt =lr.feature.chroma_cqt(y=y_harmonic, sr=sfreq)
    chroma_cqt_mean = np.mean(chroma_cqt)
    chroma_cqt_var = np.var(chroma_cqt)
    
    mfccs = lr.feature.mfcc(y=y_harmonic, sr=sfreq)
    #print(np.mean(mfccs))
    Mfccs = np.mean(mfccs)
    Mfccs_var = np.var(mfccs)
    delta = lr.feature.delta(mfccs)
    mfcc_delta_mean = np.mean(delta)
    mfcc_delta_var = np.var(delta)
    contrast=lr.feature.spectral_contrast(y=y_harmonic,sr=sfreq)
    #print(np.mean(contrast))
    Contrast = np.mean(contrast)
    Contrast_var = np.var(contrast)
    
    rolloff = lr.feature.spectral_rolloff(y=audio, sr=sfreq)
    #print(np.mean(rolloff))
    Rolloff = np.mean(rolloff)
    Rolloff_var = np.var(rolloff)
    
    zrate=lr.feature.zero_crossing_rate(y_harmonic)
    #print(np.mean(zrate) )
    Zrate = np.mean(zrate)
    Zrate_var = np.var(zrate)
    
    cent = lr.feature.spectral_centroid(y=audio, sr=sfreq)
    Cent = np.mean(cent)
    Cent_var = np.var(cent)
    
    tonnetz = lr.feature.tonnetz(y=audio, sr=sfreq)
    tonnetz_mean = np.mean(tonnetz)
    tonnetz_var = np.var(tonnetz)
    
    poly_features = lr.feature.poly_features(S=S, sr=sfreq)
    poly_features_mean = np.mean(poly_features)
    poly_features_var = np.var(poly_features)
    
    spec_bw = lr.feature.spectral_bandwidth(y=audio, sr=sfreq)
    spec_bw_mean = np.mean(spec_bw)
    spec_bw_var = np.var(spec_bw)
    
    rmse = lr.feature.rms(y=audio)
    rmse_mean = np.mean(rmse)
    rmse_var = np.var(rmse)
    
    melspectrogram = lr.feature.melspectrogram(y=audio, sr=sfreq)
    melspec_mean = np.mean(melspectrogram)
    melspec_var = np.var(melspectrogram)
    
    data = list([max_pitch,avg_pitch,var_pitch,harmonic,harmonic_var,percussive,percussive_var,Chroma_cens,Chroma_cens_var,chroma_stft_mean,chroma_stft_var,chroma_cqt_mean,chroma_cqt_var,Mfccs,Mfccs_var,mfcc_delta_mean,mfcc_delta_var,Contrast,Contrast_var,Rolloff,Rolloff_var,Zrate,Zrate_var,Cent,Cent_var,tonnetz_mean,tonnetz_var,poly_features_mean,poly_features_var,spec_bw_mean,spec_bw_var,rmse_mean,rmse_var,melspec_mean,melspec_var,label])
    df_t.loc[l] = data
    l+=1
# Out:
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=993
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=978
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=794
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=824
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=677
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=890
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=875
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=978
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=853
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=743
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=941
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=787
#   return f(*args, **kwargs)
# e:\SBME\Third Year\First Semester\DSP\Dsp_Task_3\.venv\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=838
#   return f(*args, **kwargs)

# %%
X_test = df_t.drop(columns='label',axis=1)
Y_test = df_t['label']

# %%
y_hat_test = classifier.predict(X_test)
test_data_accuracy = accuracy_score(y_hat_test, Y_test)

# %%
print('Accuracy score of the test data : ',test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.631578947368421
